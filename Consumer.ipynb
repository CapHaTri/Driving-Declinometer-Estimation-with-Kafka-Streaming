# %%
import json
import pandas as pd
from kafka import KafkaConsumer
from pyspark.sql import SparkSession
import joblib
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, DoubleType, IntegerType

# %%
spark = SparkSession.builder.appName("Driving_Declinometer").getOrCreate()

kafka_config = {
        "bootstrap_servers": 'localhost:9092',
        "value_deserializer": lambda v: json.loads(v.decode("utf-8")),
    }

KAFKA_TOPIC_NAME_CONS = "Driving_Declinometer_test"

# %%
schema = StructType([
    StructField("Epm_nEng_100ms", DoubleType(), True),
    StructField("VehV_v_100ms", DoubleType(), True),
    StructField("ActMod_trqInr_100ms", DoubleType(), True),
    StructField("RngMod_trqCrSmin_100ms", DoubleType(), True),
    StructField("CoVeh_trqAcs_100ms", DoubleType(), True),
    StructField("Clth_st_100ms", IntegerType(), True),
    StructField("CoEng_st_100ms", IntegerType(), True),
    StructField("Com_rTSC1VRVCURtdrTq_100ms", IntegerType(), True),
    StructField("Com_rTSC1VRRDTrqReq_100ms", IntegerType(), True),
])

# %%
def preprocess(received_data): 
    scaler = joblib.load('./scaler.joblib')
    driving_data = pd.DataFrame([received_data])
    columns_to_remove = ['CoVeh_trqAcs_100ms', 'Clth_st_100ms', 'CoEng_st_100ms', 'Com_rTSC1VRVCURtdrTq_100ms', 'Com_rTSC1VRRDTrqReq_100ms']
    driving_data.drop(columns=columns_to_remove, inplace=True)
    for column in driving_data.columns:
        if(driving_data[column].dtype=='object'):
            driving_data[column]=scaler.fit_transform(driving_data[column])
    return driving_data.values

# %%
def predict(data): 
    preproccessed_data = preprocess(data)
    loaded_regressor = joblib.load('./linear_regression_model.joblib')
    result = loaded_regressor.predict(preproccessed_data)
    return result

# %%
print("Kafka Consumer Application Started ... ")
consumer = KafkaConsumer(KAFKA_TOPIC_NAME_CONS,
                             bootstrap_servers=kafka_config["bootstrap_servers"])
# Out:
# Kafka Consumer Application Started ...

# %%
for message in consumer:
    
    message_value = message.value.decode('utf-8')


    message_dict = json.loads(message_value)

    print("Received Message:")
    print(message_dict)
    predict(message_dict)
        
    print("-----------------------")
    print("result ", predict(message_dict))
    print("-----------------------")
# Out:
# Received Message:
# {'Epm_nEng_100ms': 1301.5, 'VehV_v_100ms': 52.96, 'ActMod_trqInr_100ms': 0.0, 'RngMod_trqCrSmin_100ms': -140.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [113.03661295]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 912.0, 'VehV_v_100ms': 67.82, 'ActMod_trqInr_100ms': 1963.5, 'RngMod_trqCrSmin_100ms': -168.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [4487.95476539]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1213.0, 'VehV_v_100ms': 74.94, 'ActMod_trqInr_100ms': 1603.812, 'RngMod_trqCrSmin_100ms': -196.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [3706.23639924]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1143.0, 'VehV_v_100ms': 40.86, 'ActMod_trqInr_100ms': 2632.0, 'RngMod_trqCrSmin_100ms': -112.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [6061.99425115]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1159.5, 'VehV_v_100ms': 71.62, 'ActMod_trqInr_100ms': 1739.5, 'RngMod_trqCrSmin_100ms': -168.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [4008.67939175]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1145.0, 'VehV_v_100ms': 70.92, 'ActMod_trqInr_100ms': 2075.5, 'RngMod_trqCrSmin_100ms': -168.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [4768.02530827]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1133.5, 'VehV_v_100ms': 58.24, 'ActMod_trqInr_100ms': 2604.0, 'RngMod_trqCrSmin_100ms': -168.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [5978.76565486]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1096.5, 'VehV_v_100ms': 46.97, 'ActMod_trqInr_100ms': 1929.053, 'RngMod_trqCrSmin_100ms': -140.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [4459.15646874]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 893.5, 'VehV_v_100ms': 66.64, 'ActMod_trqInr_100ms': 2408.458, 'RngMod_trqCrSmin_100ms': -140.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [5492.10938068]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1162.0, 'VehV_v_100ms': 41.55, 'ActMod_trqInr_100ms': 2632.0, 'RngMod_trqCrSmin_100ms': -112.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [6063.60360426]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 903.5, 'VehV_v_100ms': 67.42, 'ActMod_trqInr_100ms': 2019.5, 'RngMod_trqCrSmin_100ms': -143.5904, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [4612.46548284]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms':

# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1093.5, 'VehV_v_100ms': 48.76, 'ActMod_trqInr_100ms': 2018.396, 'RngMod_trqCrSmin_100ms': -140.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [4658.64289925]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1164.5, 'VehV_v_100ms': 72.19, 'ActMod_trqInr_100ms': 675.5, 'RngMod_trqCrSmin_100ms': -196.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [1602.67350882]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1093.5, 'VehV_v_100ms': 56.44, 'ActMod_trqInr_100ms': 2271.5, 'RngMod_trqCrSmin_100ms': -168.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [5223.39246161]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1142.0, 'VehV_v_100ms': 70.67, 'ActMod_trqInr_100ms': 2299.5, 'RngMod_trqCrSmin_100ms': -168.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [5274.85326796]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 913.5, 'VehV_v_100ms': 68.19, 'ActMod_trqInr_100ms': 1543.5, 'RngMod_trqCrSmin_100ms': -140.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [3535.38851322]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 944.5, 'VehV_v_100ms': 70.59, 'ActMod_trqInr_100ms': 31.5, 'RngMod_trqCrSmin_100ms': -168.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [116.64563106]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1227.5, 'VehV_v_100ms': 53.56, 'ActMod_trqInr_100ms': 2235.966, 'RngMod_trqCrSmin_100ms': -168.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [5164.27728293]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1156.5, 'VehV_v_100ms': 71.47, 'ActMod_trqInr_100ms': 2299.5, 'RngMod_trqCrSmin_100ms': -168.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [5275.7303835]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 981.5, 'VehV_v_100ms': 73.09, 'ActMod_trqInr_100ms': 0.0, 'RngMod_trqCrSmin_100ms': -140.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [45.16309147]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 996.0, 'VehV_v_100ms': 62.13, 'ActMod_trqInr_100ms': 2075.5, 'RngMod_trqCrSmin_100ms': -112.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [4756.04543607]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1130.5, 'VehV_v_100ms': 76.37, 'ActMod_trqInr_100ms': 0.0, 'RngMod_trqCrSmin_100ms': -196.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [64.21785145]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1134.0, 'VehV_v_100ms': 48.61, 'ActMod_trqInr_100ms': 2632.0, 'RngMod_trqCrSmin_100ms': -112.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [6050.86119069]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1153.0, 'VehV_v_100ms': 71.33, 'ActMod_trqInr_100ms': 1655.5, 'RngMod_trqCrSmin_100ms': -168.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [3818.11023423]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1200.5, 'VehV_v_100ms': 62.53, 'ActMod_trqInr_100ms': 1542.149, 'RngMod_trqCrSmin_100ms': -196.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [3580.98896094]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 922.0, 'VehV_v_100ms': 68.65, 'ActMod_trqInr_100ms': 1579.488, 'RngMod_trqCrSmin_100ms': -140.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [3617.35326574]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1179.0, 'VehV_v_100ms': 72.86, 'ActMod_trqInr_100ms': 1455.251, 'RngMod_trqCrSmin_100ms': -168.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [3366.40673479]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 906.0, 'VehV_v_100ms': 67.35, 'ActMod_trqInr_100ms': 2464.0, 'RngMod_trqCrSmin_100ms': -140.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [5618.52819923]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1413.5, 'VehV_v_100ms': 41.31, 'ActMod_trqInr_100ms': 2688.0, 'RngMod_trqCrSmin_100ms': -140.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [6225.51602677]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1278.5, 'VehV_v_100ms': 64.9, 'ActMod_trqInr_100ms': 2607.5, 'RngMod_trqCrSmin_100ms': -196.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [5999.02658593]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1160.5, 'VehV_v_100ms': 45.56, 'ActMod_trqInr_100ms': 457.5862, 'RngMod_trqCrSmin_100ms': -140.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [1139.51539125]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1147.5, 'VehV_v_100ms': 41.17, 'ActMod_trqInr_100ms': 2632.0, 'RngMod_trqCrSmin_100ms': -112.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [6062.18720509]
# -----------------------
# Received Message:
# {'Epm_nEng_100ms': 1160.5, 'VehV_v_100ms': 71.56, 'ActMod_trqInr_100ms': 2187.5, 'RngMod_trqCrSmin_100ms': -140.0, 'CoVeh_trqAcs_100ms': 9.999747, 'Clth_st_100ms': 0, 'CoEng_st_100ms': 3, 'Com_rTSC1VRVCURtdrTq_100ms': 0, 'Com_rTSC1VRRDTrqReq_100ms': 0}
# -----------------------
# result  [5020.84079873]
# -----------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [29], line 1
# ----> 1 for message in consumer:
#       3     message_value = message.value.decode('utf-8')
#       6     message_dict = json.loads(message_value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\kafka\consumer\group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\kafka\consumer\group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\kafka\consumer\group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\kafka\consumer\group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\kafka\consumer\group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\kafka\client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\kafka\client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\selectors.py:324, in SelectSelector.select(self, timeout)
#     322 ready = []
#     323 try:
# --> 324     r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     325 except InterruptedError:
#     326     return ready
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\selectors.py:315, in SelectSelector._select(self, r, w, _, timeout)
#     314 def _select(self, r, w, _, timeout=None):
# --> 315     r, w, x = select.select(r, w, w, timeout)
#     316     return r, w + x, []
#
# KeyboardInterrupt:
